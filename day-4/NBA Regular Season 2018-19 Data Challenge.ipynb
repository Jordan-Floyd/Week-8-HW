# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %% [markdown]
# # What was the average age of player in the league?

# %%
import csv
import numpy as np
import pandas as pd


stats = pd.read_csv('../day-4/nbastats2018-2019.csv')
stats



meanAge = stats.describe().loc['mean']['Age']
print(f'The average age of a player in the league is {meanAge}')


# ANSWER -- 25.9
# Out:
# The average age of a player in the league is 25.900191938579656

# %% [markdown]
# # What player scored the most points?

# %%
stats

mostPoints = stats['Points']
mostPoints


names = stats['Name']
names

new_names = []

for name in range(len(names)):
    new_names.append(names[name])


zipped_values = list(zip(new_names, mostPoints))



sorted_points = sorted(zipped_values, key = lambda x: x[1], reverse = True)
print(sorted_points[0:1])



## Answer-- James Harden, 36.1
# Out:
# [('James Harden', 36.1)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-355e099577f4> in <module>
#      21 print(sorted_points[0:1])
#      22
# ---> 23 sorted_points.sum()
#      24
#      25 ## Answer-- James Harden, 36.1
#
# AttributeError: 'list' object has no attribute 'sum'

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
stats


stats.groupby(['Name','Blocks']).sum().sort_values('Blocks', ascending = False).head(1)


# ANSWER-- Myles Turner, highest ave blocks, couldnt get it to sum total blocks..
# Out:
#                      Height  Weight  Age  Points  Steals  Assists  Rebounds  \
# Name         Blocks
# Myles Turner 2.7         83     250   22    13.3     0.8      1.6       7.2
#
#                        FT%  FTA   FG3%  ...    MP   G   PER  OWS  DWS   WS  \
# Name         Blocks                     ...
# Myles Turner 2.7     0.736  2.7  0.388  ...  28.6  74  18.0  1.9  4.4  6.3
#
#                       WS48   USG  BPM  VORP
# Name         Blocks
# Myles Turner 2.7     0.144  20.0  3.3   2.8
#
# [1 rows x 23 columns]

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
threes = stats.groupby(['Name', 'FG3%']).mean().sort_values('FG3%', ascending = False)

threes.head(5)


## ANSWER -- 3 players: Eric Moreland, Scott Machado, Trevon Duval, Jordan Sibert all shot 100% from 3.
# Out:
#                      Height  Weight  Age  Points  Blocks  Steals  Assists  \
# Name          FG3%
# Eric Moreland 1.000      82     238   27     1.4     0.2     0.2      0.8
# Scott Machado 1.000      73     205   28     2.5     0.0     0.3      0.8
# Trevon Duval  1.000      74     189   20     1.7     0.0     0.0      0.7
# Jordan Sibert 1.000      76     187   26     3.0     0.0     0.0      0.0
# Troy Caupain  0.667      76     210   23     2.5     0.0     0.3      1.0
#
#                      Rebounds  FT%  FTA  ...   MP  G   PER  OWS  DWS   WS  \
# Name          FG3%                       ...
# Eric Moreland 1.000       4.0  NaN  0.0  ...  8.6  5   6.7 -0.1  0.1  0.0
# Scott Machado 1.000       0.0  1.0  0.3  ...  4.8  4  22.2  0.1  0.0  0.1
# Trevon Duval  1.000       0.3  NaN  0.0  ...  2.0  3  38.3  0.1  0.0  0.1
# Jordan Sibert 1.000       0.0  NaN  0.0  ...  4.0  1  29.7  0.0  0.0  0.0
# Troy Caupain  0.667       0.8  NaN  0.0  ...  4.0  4  30.7  0.1  0.0  0.1
#
# ...

# %% [markdown]
# # Who played the most minutes during the season

# %%
mostMinutes = stats.groupby(['Name', 'MP']).sum().sort_values('MP', ascending = False)

mostMinutes.head(3)

## ANSWER -- Bradley Beal, 36.9 MP
# Out:
#                    Height  Weight  Age  Points  Blocks  Steals  Assists  \
# Name         MP
# Bradley Beal 36.9      77     207   25    25.6     0.7     1.5      5.5
# Paul George  36.9      81     220   28    28.0     0.4     2.2      4.1
# James Harden 36.8      77     220   29    36.1     0.7     2.0      7.5
#
#                    Rebounds    FT%   FTA  ...   FGA   G   PER   OWS  DWS  \
# Name         MP                           ...
# Bradley Beal 36.9       5.0  0.808   5.5  ...  19.6  82  20.8   5.9  1.7
# Paul George  36.9       8.2  0.839   7.0  ...  21.0  77  23.3   7.0  4.9
# James Harden 36.8       6.6  0.879  11.0  ...  24.5  78  30.6  11.4  3.8
#
#                      WS   WS48   USG   BPM  VORP
# Name         MP
# Bradley Beal 36.9   7.6  0.120  28.4   2.8   3.7
# Paul George  36.9  11.9  0.201  29.5   5.5   5.3
# James Harden 36.8  15.2  0.254  40.5  11.7   9.9
#
# [3 rows x 23 columns]

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
clutchy = stats.groupby(['Name', 'PER']).max().sort_values('PER', ascending = False)
clutchy.head(20)

## ANSWER -- Qi Zhou, 80.4 Player Efficiency Rating
# Out:
#                             Height  Weight                    Team  Age  \
# Name                  PER
# Zhou Qi               80.4      85     210         Houston Rockets   23
# Trevon Duval          38.3      74     189                     NaN   20
# Gary Payton II        36.9      75     190      Washington Wizards   26
# Alan Williams         32.9      80     265                     NaN   26
# Giannis Antetokounmpo 30.9      83     242         Milwaukee Bucks   24
# Troy Caupain          30.7      76     210                     NaN   23
# James Harden          30.6      77     220         Houston Rockets   29
# Anthony Davis         30.3      82     253    New Orleans Pelicans   25
# Jordan Sibert         29.7      76     187           Atlanta Hawks   26
# Nikola Jokic          26.3      84     250          Denver Nuggets   23
# Karl-Anthony Towns    26.3      84     248  Minnesota Timberwolves   23
# Joel Embiid           26.1      84     250      Philadelphia 76ers   24
# ...

# %% [markdown]
# # What team had the youngest roster?

# %%
youngTeam = stats.groupby(['Team','Age']).mean().sort_values('Age', ascending = True)
youngTeam.head(12)

## ANSWER -- Lakers, average age 19(insane if true and answer is right )
# Out:
#                             Height  Weight  Points  Blocks  Steals  Assists  \
# Team                   Age
# Los Angeles Lakers     19     80.0   180.0     0.9     0.2     0.4      0.7
# Dallas Mavericks       19     79.0   218.0    21.2     0.3     1.1      6.0
# Chicago Bulls          19     82.0   255.0    10.3     1.3     0.6      1.8
# Denver Nuggets         19     81.0   214.0     1.4     0.1     0.4      0.2
# New York Knicks        19     81.0   215.0    12.8     0.3     0.6      1.1
# Philadelphia 76ers     19     76.0   199.0     6.7     0.3     0.3      1.7
# Portland Trail Blazers 19     76.0   185.0     3.8     0.0     0.1      0.7
# Memphis Grizzlies      19     83.0   242.0    13.8     1.4     0.9      1.1
# Brooklyn Nets          19     81.0   208.0     2.1     0.0     0.2      0.2
# Washington Wizards     19     79.0   215.0     4.8     0.1     0.4      1.5
# Sacramento Kings       19     83.0   234.0    14.9     1.0     0.5      1.0
# ...

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
stats[['Name','Salary']].sort_values('Salary', ascending = False)

def makeInt(row):
    if row['Salary'] == '-':
        return 0
    else:
        return int(row['Salary'])
    

stats['int_sal'] = stats.apply(makeInt, axis = 1)
stats.sort_values('int_sal', ascending = False)
# Out:
#                   Name  Height  Weight                   Team  Age    Salary  \
# 121      Stephen Curry      75     190  Golden State Warriors   30  37457154
# 253       LeBron James      80     250     Los Angeles Lakers   34  35654150
# 391         Chris Paul      72     175        Houston Rockets   33  35654150
# 496  Russell Westbrook      75     200  Oklahoma City Thunder   30  35654150
# 198      Blake Griffin      82     250        Detroit Pistons   29  32088932
# ..                 ...     ...     ...                    ...  ...       ...
# 128      Angel Delgado      82     245                    NaN   24         -
# 357   Johnathan Motley      82     230                    NaN   23         -
# 80       Deonte Burton      77     245                    NaN   25         -
# 314        Daryl Macon      75     185                    NaN   23         -
# 276        George King      78     225                    NaN   25         -
#
# ...

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
stats


freeThrow = stats.groupby(['Name', 'FT%']).min().sort_values('FT%')

freeThrow.head(50)

## ANSWER -- There are a few players with 0% FT%
# Out:
#                             Height  Weight                    Team  Age  \
# Name                 FT%
# Jacob Evans          0.000      78     210   Golden State Warriors   21
# Tahjere McCall       0.000      77     195           Brooklyn Nets   24
# Terrence Jones       0.000      81     252         Houston Rockets   27
# Donatas Motiejunas   0.000      84     222       San Antonio Spurs   28
# Haywood Highsmith    0.000      79     220                     NaN   22
# C.J. Williams        0.000      77     226                     NaN   28
# Dzanan Musa          0.000      81     208           Brooklyn Nets   19
# Melvin Frazier       0.250      78     200           Orlando Magic   22
# Ray Spalding         0.333      82     215        Dallas Mavericks   21
# Tyler Lydon          0.333      82     225          Denver Nuggets   22
# Luc Mbah a Moute     0.400      80     230    Los Angeles Clippers   32
# Kosta Koufos         0.417      84     245        Sacramento Kings   29
# ...
